# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('msd.csv', index_col=0)

# %%
print(df.to_string())
# Out:
#                                                                       name                                                               album  danceability   energy  key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  valence    tempo                      id  duration_ms  time_signature
# 0                                            Heroes - planningtorock Remix                                                   Reprise - Remixes        0.4830  0.97800    4    -4.760     0       0.0484      0.000232          0.606000    0.1120   0.7520  124.009  3d5AEtmwhwm9Sq0VWSK5qJ       267229               4
# 1                                      Porcelain - Christian Löffler Remix                                                   Reprise - Remixes        0.6160  0.34000    4   -13.648     0       0.0298      0.340000          0.727000    0.1270   0.3300   92.010  1o9e4RnIIbc9qhS0BszyjJ       232358               4
# ...
