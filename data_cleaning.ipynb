# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('moby_song_data.csv', index_col=0)

# %%
print(df.to_string())

# %%
df_nog = df.drop(index=range(20,48)).drop(index=range(187,237))

print(df_nog.to_string())
# Out:
#                                                                       name  danceability   energy  key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  valence    tempo                      id  duration_ms  time_signature
# 0                                            Heroes - planningtorock Remix        0.4830  0.97800    4    -4.760     0       0.0484      0.000232          0.606000    0.1120   0.7520  124.009  3d5AEtmwhwm9Sq0VWSK5qJ       267229               4
# 1                                      Porcelain - Christian Löffler Remix        0.6160  0.34000    4   -13.648     0       0.0298      0.340000          0.727000    0.1270   0.3300   92.010  1o9e4RnIIbc9qhS0BszyjJ       232358               4
# 2                                                 Go - Moby's Trophy Remix        0.6080  0.89000    4    -9.753     0       0.0538      0.077600          0.882000    0.0908   0.2330  124.996  7uHV6bXy6L7cwEDNsfdyUh       355293               4
# ...

# %%
# Out:
#   File "/tmp/ipykernel_601/1269392081.py", line 1
#     [1:10]
#       ^
# SyntaxError: invalid syntax
