# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('moby_song_data.csv')

# %%
df
# Out:
#      Unnamed: 0                                 name  danceability  energy  \
# 0             0        Heroes - planningtorock Remix         0.483   0.978
# 1             1  Porcelain - Christian Löffler Remix         0.616   0.340
# 2             2             Go - Moby's Trophy Remix         0.608   0.890
# 3             3          Porcelain - Bambounou Remix         0.483   0.850
# 4             4            Go - Anfisa Letyago Remix         0.674   0.958
# ..          ...                                  ...           ...     ...
# 687         687          Next Is the E - Victory Mix         0.502   0.911
# 688         688           Next Is the E - Synthe Mix         0.680   0.905
# 689         689            Next Is the E - I Feel It         0.596   0.977
# 690         690                             Thousand         0.206   0.892
# 691         691          Next Is the E - Cool WW Mix         0.608   0.811
#
# ...
